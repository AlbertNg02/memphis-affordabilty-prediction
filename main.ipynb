# %%
# imports
import pandas as pd
# %pip install geopandas
# %pip install folium
import geopandas
import folium
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
employment_df = pd.read_csv('Memphis_City_Employment_Data.csv')
funds_df = pd.read_csv('Unrestricted_Fund_Balance.csv')
econ_dev_df = pd.read_csv('Economic_Development.csv')
investment_df = pd.read_csv('HCD_Property_Investments_FY10-Q1_22.csv')

# %%
employment_df = pd.read_csv('Memphis_City_Employment_Data.csv')
funds_df = pd.read_csv('Unrestricted_Fund_Balance.csv')
econ_dev_df = pd.read_csv('Economic_Development.csv')
investment_df = pd.read_csv('HCD_Property_Investments_FY10-Q1_22.csv')

# %%
# convert the datetime column to a datetime datatype
investment_df['Completion Date'] = pd.to_datetime(investment_df['Completion Date'])
investment_df = investment_df.sort_values('Completion Date', ascending=True).reset_index(drop=True)
investment_df = investment_df.dropna(subset=['New Georeferenced Column', 'Completion Date']).reset_index(drop=True)
investment_df
# Out:
#       100 Block Address     City State  Zip code  \
# 0                   NaN  Memphis    TN   38103.0
# 1                   NaN  Memphis    TN   38108.0
# 2                   NaN  Memphis    TN   38107.0
# 3                   NaN  Memphis    TN   38127.0
# 4                   NaN  Memphis    TN   38106.0
# ...                 ...      ...   ...       ...
# 2433                NaN  Memphis    TN   38108.0
# 2434                NaN  Memphis    TN   38108.0
# 2435                NaN  Memphis    TN   38114.0
# 2436                NaN  Memphis    TN   38111.0
# 2437                NaN  Memphis    TN   38106.0
#
#                       Project Name  \
# 0               Court Square Rehab
# 1     Lead Lead hazard remediation
# 2                     Chicago Park
# 3                    Pershing Park
# 4      MIFA HARP Minor Home Repair
# ...                            ...
# 2433       Lead hazard remediation
# 2434       Lead hazard remediation
# 2435                1728 State St.
# ...

# %%
investment_df.dtypes
# Out:
# 100 Block Address                           float64
# City                                         object
# State                                        object
# Zip code                                    float64
# Project Name                                 object
# Project Type                                 object
# Status                                       object
# Completion Date                      datetime64[ns]
# Units                                       float64
# Property Type                                object
# Tenure Type                                  object
# Activity/Dev. Type                           object
# Funding Type                                 object
# Organization                                 object
# Total Budgeted                              float64
# Lat                                         float64
# Long                                        float64
# New Georeferenced Column                     object
# ...

# %%
# Keep only relevant columns
investment_df_map = investment_df.loc[:, ("Completion Date", "Project Name", "Zip code", "Lat", "Long", "Project Type")]
investment_df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2438 entries, 0 to 2437
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Completion Date  2438 non-null   datetime64[ns]
#  1   Project Name     2438 non-null   object
#  2   Zip code         2437 non-null   float64
#  3   Lat              2438 non-null   float64
#  4   Long             2438 non-null   float64
#  5   Project Type     2434 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 114.4+ KB
